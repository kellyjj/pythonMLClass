# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

df = pd.read_csv('/home/kellyj/Programing/PythonProjects/temp/Ames_Housing_Data_Final.csv')
df2 = pd.read_csv('/home/kellyj/Programing/PythonProjects/ML_Udemy/NoteBooks/UNZIP_ME_FOR_NOTEBOOKS_V4/DATA/AMES_Final_DF.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2925 entries, 0 to 2924
# Data columns (total 93 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0.6       2925 non-null   int64
#  1   Unnamed: 0.5       2925 non-null   int64
#  2   Unnamed: 0.4       2925 non-null   int64
#  3   Unnamed: 0.3       2925 non-null   int64
#  4   Unnamed: 0.2       2925 non-null   int64
#  5   Unnamed: 0.1       2925 non-null   int64
#  6   Unnamed: 0         2925 non-null   int64
#  7   MS SubClass        2925 non-null   int64
#  8   Lot Frontage       2925 non-null   float64
#  9   Lot Area           2925 non-null   int64
#  10  Land Contour       2925 non-null   object
#  11  Utilities          2925 non-null   object
#  12  Lot Config         2925 non-null   object
#  13  Land Slope         2925 non-null   object
#  14  Neighborhood       2925 non-null   object
#  15  Condition 1        2925 non-null   object
# ...

# %%
my_obj_df = df.select_dtypes(include='object')
my_num_df = df.select_dtypes(exclude='object')

# %%
df = pd.get_dummies(df,columns=['Lot Shape'])

# %%
# df[['Street_Grvl','Street_Pave']]
df['Lot Shape_Reg']
# Out:
# 0       0
# 1       1
# 2       0
# 3       1
# 4       0
#        ..
# 2920    0
# 2921    0
# 2922    1
# 2923    1
# 2924    1
# Name: Lot Shape_Reg, Length: 2925, dtype: uint8

# %%
df[df['MS Zoning_RM']==1]
# Out:
#       Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  MS SubClass  Lot Frontage  \
# 29              29            29          29          160          21.0
# 30              30            30          30          160          21.0
# 31              31            31          31          160          21.0
# 83              83            83          83           90          68.0
# 169            169           169         169           50          60.0
# ...            ...           ...         ...          ...           ...
# 2911          2911          2913        2916          180          21.0
# 2912          2912          2914        2917          160          21.0
# 2913          2913          2915        2918          160          21.0
# 2914          2914          2916        2919          160          21.0
# 2915          2915          2917        2920          160          21.0
#
#       Lot Area Street Lot Shape Land Contour Utilities  ... Sale Type  \
# ...

# %%
df.to_csv('/home/kellyj/Programing/PythonProjects/temp/Ames_Housing_Data_Final.csv')
