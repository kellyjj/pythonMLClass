# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x= np.arange(0,10)

# %%
y= 2*x

# %%
#this is a example of how to use the functional methods of plotting
plt.plot(x,y)
plt.title("The Tower")
plt.xlim(0,8)
plt.ylim(0,17)
plt.xlabel("Brandy")
plt.ylabel("Kelly")
plt.savefig("/home/kellyj/Documents/Katet.png")

# %%
#here we will do oop plotting

# %%
myfig = plt.figure()
myaxis = myfig.add_axes([0,0,1,1])
myaxis.plot(x,y)

# %%
a = np.linspace(0,10,11)
b= a**4
x=np.arange(0,10)
y = x*2

# %%
fig = plt.figure()

axes = fig.add_axes([0,0,1,1])
axes.set_xlim(0,8)
axes.set_ylim(0,8000)
axes.set_xlabel("a")
axes.set_ylabel("b")
axes.set_title("The power devil")
axes.plot(a,b)

axes2 = fig.add_axes([.2,.5,.33,.33])
axes2.set_xlim(1,2)
axes2.set_ylim(0,100)
axes2.set_xlabel("a")
axes2.set_ylabel("b")
axes2.set_title("Zoomed In Devil")
axes2.plot(x,y)

# %%
fig = plt.figure(figsize=(5,5),dpi=500)
axes = fig.add_axes([0,0,1,1])
axes.plot(a,b)
fig.savefig('/home/kellyj/Documents/saveme.png',bbox_inches='tight')

# %%
a= np.linspace(0,10,11)
b= a**4
x= np.arange(0,10)
y= x*2

# %%
fig,axes = plt.subplots(nrows=2,ncols=2)
axes
axes[0][0].plot(x,y)
axes[0][1].plot(a,b)
axes[1][0].plot(x,y)
axes[1][1].plot(a,b)
plt.tight_layout()

# %%
fig,axes = plt.subplots(nrows=2,ncols=2)
axes
axes[0][0].plot(x,y)
axes[0][1].plot(a,b)
axes[1][0].plot(x,y)
axes[1][1].plot(a,b)
fig.subplots_adjust(hspace=.5,wspace=.5)

# %%
fig = plt.figure()
axes = fig.add_axes([0,0,1,1])
x= np.linspace(0,11,10)
axes.plot(x,label='plain x')
axes.plot(x,x**2,label="xSquared")
axes.legend(loc=(1.1,.5))

# %%
fig = plt.figure()
axes = fig.add_axes([0,0,1,1])
x= np.linspace(0,11,10)
axes.plot(x,label='plain x',color='gold',lw=5,ls=':')
lines = axes.plot(x,x**2,label="xSquared",color='#a8325e')
lines[0].set_dashes([1,1,1,2,3,5])
axes.legend(loc=(1.1,.5))

# %%
fig = plt.figure()
axes = fig.add_axes([0,0,1,1])
x= np.linspace(0,11,10)
axes.plot(x,label='plain x',color='gold',lw=1,ls='-',marker='X',markersize=10,markerfacecolor='red',markeredgewidth=3,markeredgecolor='pink')
axes.legend(loc=(1.1,.5))
