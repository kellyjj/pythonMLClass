# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy
import seaborn as sns

# %%
# df = pd.read_csv('/home/kellyj/Programing/PythonProjects/temp/Ames_Housing_Data_NoOutLiers_Missing_fixed.csv')
df = pd.read_csv('/home/kellyj/Programing/PythonProjects/temp/Ames_Housing_Data_Final.csv')

# %%
# df['MS SubClass'] = df['MS SubClass'].apply(str)

# %%
df.select_dtypes(include='object')
# Out:
#      Land Contour Utilities Lot Config Land Slope Neighborhood Condition 1  \
# 0             Lvl    AllPub     Corner        Gtl        NAmes        Norm
# 1             Lvl    AllPub     Inside        Gtl        NAmes       Feedr
# 2             Lvl    AllPub     Corner        Gtl        NAmes        Norm
# 3             Lvl    AllPub     Corner        Gtl        NAmes        Norm
# 4             Lvl    AllPub     Inside        Gtl      Gilbert        Norm
# ...           ...       ...        ...        ...          ...         ...
# 2920          Lvl    AllPub    CulDSac        Gtl      Mitchel        Norm
# 2921          Low    AllPub     Inside        Mod      Mitchel        Norm
# 2922          Lvl    AllPub     Inside        Gtl      Mitchel        Norm
# 2923          Lvl    AllPub     Inside        Mod      Mitchel        Norm
# 2924          Lvl    AllPub     Inside        Mod      Mitchel        Norm
#
# ...

# %%
my_obj_df = df.select_dtypes(include='object')
my_num_df = df.select_dtypes(exclude='object')

# %%
my_obj_df
# Out:
#      Land Contour Utilities Lot Config Land Slope Neighborhood Condition 1  \
# 0             Lvl    AllPub     Corner        Gtl        NAmes        Norm
# 1             Lvl    AllPub     Inside        Gtl        NAmes       Feedr
# 2             Lvl    AllPub     Corner        Gtl        NAmes        Norm
# 3             Lvl    AllPub     Corner        Gtl        NAmes        Norm
# 4             Lvl    AllPub     Inside        Gtl      Gilbert        Norm
# ...           ...       ...        ...        ...          ...         ...
# 2920          Lvl    AllPub    CulDSac        Gtl      Mitchel        Norm
# 2921          Low    AllPub     Inside        Mod      Mitchel        Norm
# 2922          Lvl    AllPub     Inside        Gtl      Mitchel        Norm
# 2923          Lvl    AllPub     Inside        Mod      Mitchel        Norm
# 2924          Lvl    AllPub     Inside        Mod      Mitchel        Norm
#
# ...

# %%
df_obj_dummies = pd.get_dummies(my_obj_df,drop_first=True)

# %%
final_df = pd.concat([my_num_df,df_obj_dummies],axis=1)

# %%
# final_df['']

# %%
final_df.to_csv('/home/kellyj/Programing/PythonProjects/temp/Ames_Housing_Data_Final.csv')
